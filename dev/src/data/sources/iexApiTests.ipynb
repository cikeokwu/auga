# %%
import pandas as pd
import pandas_datareader.data as web
import pandas_datareader
import datetime
import numpy as np
from iexfinance import get_available_symbols, Stock
import iexfinance

# %% [markdown]
# ## Here is where we test querying the IEX api

# %%
# For testing, we're grabbing 1` years worth of stock data

start = datetime.datetime(2016,1,1)

end = datetime.datetime(2019, 1, 1)

# %%
f = web.DataReader('MSFT', 'iex', start, end)

# %%
DF =get_available_symbols()

# %%
stocko = pd.DataFrame(DF)
stockSymbols = stocko['symbol'].unique()
totalTickers = len(stockSymbols)
Stock([stockSymbols[i] for i in range(0,100)], output_format='pandas').get_quote().transpose()
#Stock([stockSymbols[i] for i in range(0,100)],output_format="pandas").get_peers()
# Out:
# /home/robot-tumas/pyEnv/wiggles/lib/python3.5/site-packages/iexfinance/__init__.py:45: UserWarning: Stock is moved to iexfinance.stocks. This function will in be deprecated in v0.4.0
#   warnings.warn(WNG_MSG % ("Stock", "stocks"))
#       avgTotalVolume calculationPrice  change changePercent    close  \
# A            1810869            close    1.28       0.01662     78.3
# AA           4471773            close    0.07       0.00248    28.27
# AAAU           50875            close   0.085       0.00648     13.2
# AABA         6893205            close   -0.76      -0.01108    67.86
# AAC           310256            close       0             0     2.97
# AADR           15906            close    0.42       0.00933    45.43
# AAL          8743046            close   -1.06      -0.02935    35.05
# AAMC            6180            close   -0.49      -0.01422    33.98
# AAME            2962            close       0             0     2.73
# AAN           565284            close   -0.78       -0.0145    53.02
# AAOI          645182            close    0.31       0.02106    15.03
# AAON          107871            close       1         0.026    39.46
# AAP          1249975            close    1.25       0.00741   169.99
# AAPL        33192603            close   -0.38      -0.00222   170.42
# AAT           193187            close    0.32       0.00732    44.05
# AAU           212864            close -0.0003      -0.00042     0.71
# AAWW          270591            close   -0.05      -0.00092    54.23
# AAXJ         1259204            close   -0.33      -0.00481    68.26
# AAXN          441842            close    0.84       0.01539    55.43
# AB            400364            close    0.16       0.00536       30
# ABB          3035240            close    0.47       0.02429    19.82
# ABBV         7740701            close    0.33        0.0041    80.85
# ABC          1537044            close    0.61       0.00709    86.66
# ABCB          401069            close     1.4       0.03656    39.69
# ABDC           33337            close   -0.05      -0.00678     7.32
# ABEO          373953            close    0.13          0.02     6.63
# ABEOW              0            close       0             0     3.35
# ABEV        35028036            close       0             0     4.95
# ABG           212912            close    1.91       0.02729     71.9
# ABIL          646750            close  -0.008      -0.00417     1.91
# ...              ...              ...     ...           ...      ...
# ACRX         1635508            close    0.27       0.10266      2.9
# ACSG             468            close    0.24       0.00946    25.62
# ACSI            3425            close  0.2377       0.00739  32.4066
# ACST          342593            close  -0.014      -0.01515     0.91
# ACT             5026            close  0.1788       0.00734  24.5522
# ACTG           95669            close    0.06       0.01923     3.18
# ACU             5052            close   -0.42      -0.02497     16.4
# ACV            31680            close       0             0    21.62
# ACWF          154523            close  0.3047       0.01059  29.0647
# ACWI         4718634            close    0.72       0.01032    70.51
# ACWV          308206            close    0.76       0.00882    86.91
# ACWX         3587890            close    0.47       0.01046    45.41
# ACY             1722            close       0             0     11.5
# ADAP          270184            close     0.1       0.02066     4.94
# ADBE         3058146            close   -0.69      -0.00265   259.45
# ADC           257807            close    0.53       0.00814    65.65
# ADES           70444            close    0.19       0.01649    11.71
# ADI          2864257            close    1.25       0.01196   105.74
# ADIL          469085            close    -0.1      -0.02326      4.2
# ADILW          22918            close  0.1369       0.22443   0.7469
# ADM          3640907            close    0.09       0.00215    41.98
# ADMA          594168            close     0.4       0.10471     4.22
# ADMP          362873            close    0.02       0.00645     3.12
# ADMS          460686            close    0.61       0.06149    10.53
# ADNT         2641802            close    0.89       0.04566    20.38
# ADOM          723891            close -0.0171      -0.04273   0.3831
# ADP          2434813            close    1.52       0.01026   149.67
# ADRA             359            close  0.2231       0.00735  30.5835
# ADRD           32979            close  0.2274       0.01086  21.1701
# ADRE            7177            close -0.1835      -0.00459  39.7992
#
#            closeTime                                        companyName  \
# A      1550264577839                          Agilent Technologies Inc.
# AA     1550264551113                                  Alcoa Corporation
# AAAU   1550264400203                           Perth Mint Physical Gold
# AABA   1550264400618                                        Altaba Inc.
# AAC    1550264521069                                  AAC Holdings Inc.
# AADR   1550264400208                    AdvisorShares Dorsey Wright ADR
# AAL    1550264400388                       American Airlines Group Inc.
# AAMC   1550264400055               Altisource Asset Management Corp Com
# AAME   1550264400624                      Atlantic American Corporation
# AAN    1550264419025                                       Aaron's Inc.
# AAOI   1550264400782                       Applied Optoelectronics Inc.
# AAON   1550264400228                                          AAON Inc.
# AAP    1550264523085                         Advance Auto Parts Inc W/I
# AAPL   1550264400567                                         Apple Inc.
# AAT    1550264523067                         American Assets Trust Inc.
# AAU    1550264400099                              Almaden Minerals Ltd.
# AAWW   1550264400621                       Atlas Air Worldwide Holdings
# AAXJ   1550264400500  iShares MSCI All Country Asia ex Japan Index Fund
# AAXN   1550264400545                               Axon Enterprise Inc.
# AB     1550264523068               AllianceBernstein Holding L.P. Units
# ABB    1550264523087                                            ABB Ltd
# ABBV   1550264535706                                        AbbVie Inc.
# ABC    1550264546304                      AmerisourceBergen Corporation
# ABCB   1550264400745                                     Ameris Bancorp
# ABDC   1550264400268                             Alcentra Capital Corp.
# ABEO   1550264400599                           Abeona Therapeutics Inc.
# ABEOW  1549314000606
# ABEV   1550264473699  Ambev S.A. American Depositary Shares (Each re...
# ABG    1550264430758                        Asbury Automotive Group Inc
# ABIL   1550264400246                                       Ability Inc.
# ...              ...                                                ...
# ACRX   1550264400295                        AcelRx Pharmaceuticals Inc.
# ACSG   1550264400160      Xtrackers MSCI ACWI ex USA ESG Leaders Equity
# ACSI   1550264400000                     American Customer Satisfaction
# ACST   1550264400581                                 Acasti Pharma Inc.
# ACT    1550264400528                             AdvisorShares Vice ETF
# ACTG   1550264400758                        Acacia Research Corporation
# ACU    1550264400044                           Acme United Corporation.
# ACV    1550264520715  AllianzGI Diversified Income & Convertible Fun...
# ACWF   1550264400204               iShares Edge MSCI Multifactor Global
# ACWI   1550264400284                       iShares MSCI ACWI Index Fund
# ACWV   1550264400000                   iShares Edge MSCI Min Vol Global
# ACWX   1550264400376                 iShares MSCI ACWI ex US Index Fund
# ACY    1550264400063                                  AeroCentury Corp.
# ADAP   1550264400219                       Adaptimmune Therapeutics plc
# ADBE   1550264400735                                         Adobe Inc.
# ADC    1550264521035                           Agree Realty Corporation
# ADES   1550264400317                  Advanced Emissions Solutions Inc.
# ADI    1550264400214                                Analog Devices Inc.
# ADIL   1550264400256                          Adial Pharmaceuticals Inc
# ADILW  1550264400502                  Adial Pharmaceuticals Inc Warrant
# ADM    1550264406412                     Archer-Daniels-Midland Company
# ADMA   1550264400206                                 ADMA Biologics Inc
# ADMP   1550264400585                 Adamis Pharmaceuticals Corporation
# ADMS   1550264400483                        Adamas Pharmaceuticals Inc.
# ADNT   1550264533544                                         Adient plc
# ADOM   1550264400249                                       ADOMANI Inc.
# ADP    1550264400304                     Automatic Data Processing Inc.
# ADRA   1550264400730               Invesco BLDRS Asia 50 ADR Index Fund
# ADRD   1550264400623  Invesco BLDRS Developed Markets 100 ADR Index ...
# ADRE   1550264400299   Invesco BLDRS Emerging Markets 50 ADR Index Fund
#
#       delayedPrice delayedPriceTime extendedChange     ...        open  \
# A             78.3    1550264577839              0     ...       77.67
# AA           28.27    1550264551113              0     ...       28.76
# AAAU          13.2    1550265000001          -0.15     ...       13.18
# AABA         67.86    1550264400618              0     ...       68.95
# AAC           2.97    1550264521069              0     ...        2.99
# AADR         45.43    1550265000001           -5.4     ...       45.26
# AAL          35.05    1550264400388           0.03     ...       36.24
# AAMC         33.98    1550265000004          -3.96     ...        34.4
# AAME          2.75    1550264400624          -0.13     ...        2.75
# AAN          53.02    1550264419025              0     ...       53.76
# AAOI         15.03    1550264400782              0     ...       14.81
# AAON         39.46    1550264400228              0     ...       38.49
# AAP         169.99    1550264523085          -0.14     ...      169.83
# AAPL        170.42    1550264400567          -0.04     ...      171.47
# AAT          44.05    1550264523067              0     ...       43.89
# AAU           0.71    1550265000002          -0.01     ...       0.702
# AAWW         54.23    1550264400621              0     ...       54.35
# AAXJ         68.26    1550264400500           0.33     ...       68.33
# AAXN         55.43    1550264400545              0     ...        54.9
# AB              30    1550264523068              0     ...       29.95
# ABB          19.82    1550264523087              0     ...       19.73
# ABBV         80.85    1550264535706          -0.27     ...       81.14
# ABC          86.66    1550264546304              0     ...        86.7
# ABCB         39.69    1550264400745              0     ...       38.64
# ABDC          7.32    1550264400268              0     ...        7.34
# ABEO          6.63    1550264400599           0.02     ...        6.52
# ABEOW         3.35    1549314000606           None     ...        3.34
# ABEV          4.95    1550264473699          0.013     ...           5
# ABG           71.9    1550264430758              0     ...        70.6
# ABIL          1.91    1550264400246              0     ...        1.92
# ...            ...              ...            ...     ...         ...
# ACRX           2.9    1550264400295              0     ...        2.74
# ACSG         25.62    1550265000001          -1.76     ...       25.71
# ACSI         32.37    1550264400745        -2.1066     ...       32.12
# ACST          0.91    1550264400581           0.02     ...        0.92
# ACT          24.55    1550264400528        -0.0122     ...       24.72
# ACTG          3.18    1550264400758              0     ...        3.15
# ACU           16.4    1550265000000          -0.52     ...          17
# ACV          21.62    1550264520715              0     ...       21.56
# ACWF        29.065    1550265000002        -0.3847     ...       28.95
# ACWI         70.51    1550264400284              0     ...       70.25
# ACWV          86.9    1550264400570          -0.71     ...        86.6
# ACWX         45.41    1550264400376          -0.52     ...       45.24
# ACY           11.5    1550265000002          -1.08     ...        11.7
# ADAP          4.94    1550264400219           0.06     ...        4.84
# ADBE        259.45    1550264400735          -0.62     ...      260.34
# ADC          65.65    1550264521035              0     ...       65.26
# ADES         11.71    1550264400317              0     ...       11.63
# ADI         105.74    1550264400214         -0.505     ...      105.37
# ADIL           4.2    1550264400256          -0.03     ...        4.36
# ADILW         0.75    1550264400502        -0.0969     ...      0.7299
# ADM          41.98    1550264406412              0     ...       42.27
# ADMA          4.22    1550264400206              0     ...        3.86
# ADMP          3.12    1550264400585              0     ...         3.1
# ADMS         10.53    1550264400483              0     ...          10
# ADNT         20.38    1550264533544          -0.32     ...       19.79
# ADOM        0.3831    1550264400249         0.0164     ...        0.45
# ADP         149.67    1550264400304          -0.87     ...      149.55
# ADRA         30.47    1550264400730        -0.5835     ...       30.47
# ADRD         21.16    1550264400623        -2.2801     ...        21.1
# ADRE         39.88    1550264400299         0.2008     ...       39.96
#
#             openTime peRatio previousClose           primaryExchange  \
# A      1550241001006   28.06         77.02   New York Stock Exchange
# AA     1550241001005     7.9          28.2   New York Stock Exchange
# AAAU   1550241000128    None        13.115                 NYSE Arca
# AABA   1550241000602    None         68.62      Nasdaq Global Select
# AAC    1550241001002   12.38          2.97   New York Stock Exchange
# AADR   1550241000089    None         45.01                 NYSE Arca
# AAL    1550241000222     7.7         36.11      Nasdaq Global Select
# AAMC   1550255138441    None         34.47             NYSE American
# AAME   1550241000871    None          2.73      NASDAQ Global Market
# AAN    1550241001005   15.78          53.8   New York Stock Exchange
# AAOI   1550241000814   10.09         14.72      NASDAQ Global Market
# AAON   1550241000943   49.95         38.46      Nasdaq Global Select
# AAP    1550241001014   25.26        168.74   New York Stock Exchange
# AAPL   1550241000795   14.36         170.8      Nasdaq Global Select
# AAT    1550241001904   21.08         43.73   New York Stock Exchange
# AAU    1550241000031    None        0.7103             NYSE American
# AAWW   1550241000746    8.24         54.28      Nasdaq Global Select
# AAXJ   1550241000667    None         68.59      NASDAQ Global Market
# AAXN   1550241000857    89.4         54.59      Nasdaq Global Select
# AB     1550241001905   11.19         29.84   New York Stock Exchange
# ABB    1550241001006   14.68         19.35   New York Stock Exchange
# ABBV   1550241107013   10.22         80.52   New York Stock Exchange
# ABC    1550241001012   13.37         86.05   New York Stock Exchange
# ABCB   1550241000154   11.88         38.29      Nasdaq Global Select
# ABDC   1550241000411    7.18          7.37      Nasdaq Global Select
# ABEO   1550241000529   -6.91           6.5     NASDAQ Capital Market
# ABEOW  1549297562069    None          3.35
# ABEV   1550241064289    22.5          4.95   New York Stock Exchange
# ABG    1550241025847    8.54         69.99   New York Stock Exchange
# ABIL   1550241000452    None         1.918     NASDAQ Capital Market
# ...              ...     ...           ...                       ...
# ACRX   1550241000617   -3.45          2.63      NASDAQ Global Market
# ACSG   1549388900692    None         25.38                 NYSE Arca
# ACSI   1550241000000    None       32.1689  Cboe Global Markets EDGX
# ACST   1550241000738    None         0.924     NASDAQ Capital Market
# ACT    1550241000981    None       24.3734      NASDAQ Global Market
# ACTG   1550241000484   -2.89          3.12      Nasdaq Global Select
# ACU    1550241173367   12.91         16.82             NYSE American
# ACV    1550241001001    None         21.62   New York Stock Exchange
# ACWF   1550241000098    None         28.76                 NYSE Arca
# ACWI   1550241000895    None         69.79      NASDAQ Global Market
# ACWV   1550241000000    None         86.15  Cboe Global Markets EDGX
# ACWX   1550241000936    None         44.94      NASDAQ Global Market
# ACY    1550258593017   18.55          11.5             NYSE American
# ADAP   1550241001042   -5.15          4.84      Nasdaq Global Select
# ADBE   1550241000169    46.5        260.14      Nasdaq Global Select
# ADC    1550241001006   23.04         65.12   New York Stock Exchange
# ADES   1550241000913    5.86         11.52      NASDAQ Global Market
# ADI    1550241000965   17.77        104.49      Nasdaq Global Select
# ADIL   1550241000668    None           4.3     NASDAQ Capital Market
# ADILW  1550259088348    None          0.61     NASDAQ Capital Market
# ADM    1550241028669   11.99         41.89   New York Stock Exchange
# ADMA   1550241000822   -3.32          3.82     NASDAQ Capital Market
# ADMP   1550241000959   -3.22           3.1     NASDAQ Capital Market
# ADMS   1550241001014   -2.06          9.92      NASDAQ Global Market
# ADNT   1550241001001     3.6         19.49   New York Stock Exchange
# ADOM   1550241000912    None        0.4002     NASDAQ Capital Market
# ADP    1550241000846   34.49        148.15      Nasdaq Global Select
# ADRA   1550241000301    None       30.3604      NASDAQ Global Market
# ADRD   1550241000889    None       20.9427      NASDAQ Global Market
# ADRE   1550241000758    None       39.9827      NASDAQ Global Market
#
#                    sector symbol week52High week52Low   ytdChange
# A              Healthcare      A      78.31     60.42    0.208582
# AA        Basic Materials     AA      62.35     25.01   0.0798428
# AAAU                        AAAU      14.85   11.7394   0.0179743
# AABA   Financial Services   AABA      82.45     54.75    0.169299
# AAC            Healthcare    AAC      12.96      1.33    0.822086
# AADR                        AADR      62.39     38.15    0.135787
# AAL           Industrials    AAL      57.44     28.81   0.0527173
# AAMC   Financial Services   AAMC    73.4983      22.6    0.118069
# AAME   Financial Services   AAME        3.9             0.0963855
# AAN           Industrials    AAN         56     38.77    0.204911
# AAOI           Technology   AAOI       50.3     13.42  -0.0324664
# AAON      Basic Materials   AAON       44.9     29.05    0.151178
# AAP     Consumer Cyclical    AAP     186.15    102.15   0.0838411
# AAPL           Technology   AAPL     233.47       142    0.081563
# AAT           Real Estate    AAT      44.25     30.62    0.128185
# AAU       Basic Materials    AAU       0.98      0.48    0.016772
# AAWW          Industrials   AAWW    75.2911     35.59    0.299248
# AAXJ                        AAXJ      80.25     60.48   0.0771364
# AAXN          Industrials   AAXN    76.4544     27.19    0.244164
# AB     Financial Services     AB    31.4194     23.34     0.10547
# ABB           Industrials    ABB       25.6    18.045   0.0674479
# ABBV           Healthcare   ABBV        122     75.77  -0.0787019
# ABC            Healthcare    ABC     101.56     69.36    0.176504
# ABCB   Financial Services   ABCB      59.05     29.97    0.278814
# ABDC   Financial Services   ABDC      7.859      5.58   0.0956296
# ABEO           Healthcare   ABEO         22     6.259   -0.036899
# ABEOW                      ABEOW       3.35         0  -0.0279712
# ABEV   Consumer Defensive   ABEV       7.43      3.77    0.178571
# ABG     Consumer Cyclical    ABG      77.75      58.6   0.0827803
# ABIL           Technology   ABIL      14.55    0.3233  -0.0246828
# ...                   ...    ...        ...       ...         ...
# ACRX           Healthcare   ACRX       5.05      1.65    0.272015
# ACSG                        ACSG      25.83     22.95   0.0918428
# ACSI                        ACSI      34.49     27.86    0.123781
# ACST           Healthcare   ACST        1.8    0.4333 -0.00403889
# ACT                          ACT      27.73   20.8801    0.158809
# ACTG          Industrials   ACTG        4.4      2.75   0.0450365
# ACU    Consumer Defensive    ACU    24.9799      13.5   0.0804418
# ACV    Financial Services    ACV      25.31     17.51    0.159131
# ACWF                        ACWF     32.047     24.88    0.130186
# ACWI                        ACWI    74.9512     61.01    0.109634
# ACWV                        ACWV      88.22     78.03   0.0843057
# ACWX                        ACWX      51.51     40.51   0.0965638
# ACY           Industrials    ACY     17.345      8.36    0.261601
# ADAP           Healthcare   ADAP     14.625       3.6  -0.0876432
# ADBE           Technology   ADBE     277.61    199.18    0.152669
# ADC           Real Estate    ADC      66.71     45.05    0.147699
# ADES          Industrials   ADES      12.37     8.535    0.134635
# ADI            Technology    ADI     105.83     76.62     0.24264
# ADIL           Healthcare   ADIL       9.44    1.1055   -0.377106
# ADILW                      ADILW     2.4499      0.26    0.233891
# ADM    Consumer Defensive    ADM     52.065     39.16   0.0358677
# ADMA           Healthcare   ADMA       6.96      2.08    0.715397
# ADMP           Healthcare   ADMP        5.1      2.01    0.311889
# ADMS           Healthcare   ADMS     34.715      7.42     0.22246
# ADNT    Consumer Cyclical   ADNT       67.1   14.5184    0.347896
# ADOM    Consumer Cyclical   ADOM       1.97     0.155    0.200294
# ADP           Industrials    ADP     153.51    109.14    0.160329
# ADRA                        ADRA      36.38     27.42   0.0907188
# ADRD                        ADRD      23.89   18.8678   0.0910939
# ADRE                        ADRE      46.99   34.9744   0.0855004
#
# [100 rows x 40 columns]

# %%
#returns 5 year historical stock data for every stock. 
def get5yHistorical(stockSymbols, totalTickers):
    bigDF = Stock(stockSymbols[0],output_format="pandas").get_chart(range='5y').transpose()
    bigDF['ticker']=stockSymbols[0]
    bigDF.index= [bigDF['ticker'],bigDF.index]
    for i in range(1,totalTickers):
        try:
            print(" iteration:",i," ","ticker: ",stockSymbols[i], 'percentage:',i/totalTickers*100,end='\r')
            trial=pd.DataFrame(Stock(stockSymbols[i],output_format="pandas").get_chart(range='5y').transpose())
            trial['ticker']=stockSymbols[i]
            trial.index= [trial['ticker'],trial.index]
            bigDF = bigDF.append(trial)
        except KeyError:
            print('this key had an error:', stockSymbols[i], 'at position:',i)
            pass
        
    return bigDF
result=get5yHistorical(stockSymbols,totalTickers)
# Out:
#  iteration: 2   ticker:  AAAU percentage: 0.022901637467078895
# /home/robot-tumas/pyEnv/wiggles/lib/python3.5/site-packages/pandas/core/frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# this key had an error: ARNC-RNC- percentage: 5.62235199816786954
# this key had an error: BFL BFL percentage: 9.114851711897401283
# this key had an error: DELT DELT percentage: 22.26039161800069647083   ticker:  BUYN percentage: 12.401236688423223
# this key had an error: DTLA-DTLA- percentage: 24.642161914576892
#  iteration: 2509   ticker:  ERF percentage: 28.73010420245047383

# %%
bigDF = pd.DataFrame(Stock(stockSymbols[0],output_format="pandas").get_chart(range='5y').transpose())
#bigDF.append(pd.Stock(stockSymbols[1],output_format="pandas").get_chart(range='5y').transpose())


trial = pd.DataFrame(Stock(stockSymbols[13],output_format="pandas").get_chart(range='5y').transpose())
trial['ticker']=stockSymbols[13]
trial.index= [trial['ticker'],trial.index]
bigDF.append(trial)
# Out:
# date           2014-02-18 00:00:00  2014-02-19 00:00:00  2014-02-20 00:00:00  \
# ticker
# A      open           3.770190e+01         3.745000e+01         3.821930e+01
#        high           3.815130e+01         3.856650e+01         3.916900e+01
#        low            3.741600e+01         3.737520e+01         3.815470e+01
#        close          3.754540e+01         3.808320e+01         3.900220e+01
#        volume         6.553839e+06         4.838795e+06         4.629755e+06
# AAPL   open           7.170720e+01         7.154300e+01         6.999860e+01
#        high           7.238880e+01         7.182410e+01         7.052520e+01
#        low            7.165600e+01         7.017720e+01         6.947460e+01
#        close          7.170590e+01         7.057380e+01         6.975690e+01
#        volume         6.530625e+07         7.855442e+07         7.652910e+07
#
# date           2014-02-21 00:00:00  2014-02-24 00:00:00  2014-02-25 00:00:00  \
# ticker
# A      open           3.897500e+01         3.843040e+01         3.866870e+01
#        high           3.907710e+01         3.879120e+01         3.919290e+01
#        low            3.834190e+01         3.839630e+01         3.863460e+01
#        close          3.835550e+01         3.863460e+01         3.872990e+01
#        volume         2.407171e+06         2.392783e+06         3.375173e+06
# AAPL   open           6.997270e+01         6.870630e+01         6.952450e+01
#        high           7.020610e+01         6.959540e+01         6.954880e+01
#        low            6.889670e+01         6.861040e+01         6.842390e+01
#        close          6.898210e+01         6.928410e+01         6.856310e+01
#        volume         6.975725e+07         7.236495e+07         5.824735e+07
#
# date           2014-02-26 00:00:00  2014-02-27 00:00:00  2014-02-28 00:00:00  \
# ticker
# A      open           3.879120e+01         3.881840e+01         3.843040e+01
#        high           3.922690e+01         3.899540e+01         3.887970e+01
#        low            3.863460e+01         3.825340e+01         3.839630e+01
#        close          3.887290e+01         3.836910e+01         3.875720e+01
#        volume         2.400946e+06         3.123781e+06         2.876261e+06
# AAPL   open           6.876670e+01         6.791700e+01         6.948510e+01
#        high           6.894920e+01         6.944570e+01         6.996710e+01
#        low            6.771470e+01         6.777380e+01         6.857100e+01
#        close          6.794460e+01         6.929990e+01         6.911210e+01
#        volume         6.913129e+07         7.555732e+07         9.307465e+07
#
# date           2014-03-03 00:00:00   ...    2019-02-05 00:00:00  \
# ticker                               ...
# A      open           3.820570e+01   ...           7.580000e+01
#        high           3.888650e+01   ...           7.651000e+01
#        low            3.797770e+01   ...           7.579000e+01
#        close          3.860740e+01   ...           7.631000e+01
#        volume         2.488373e+06   ...           1.593537e+06
# AAPL   open           6.874170e+01   ...           1.721217e+02
#        high           6.969130e+01   ...           1.743322e+02
#        low            6.866160e+01   ...           1.716140e+02
#        close          6.931170e+01   ...           1.734361e+02
#        volume         5.966792e+07   ...           3.610163e+07
#
# date           2019-02-06 00:00:00  2019-02-07 00:00:00  2019-02-08 00:00:00  \
# ticker
# A      open           7.611000e+01         7.572000e+01                75.07
#        high           7.669000e+01         7.612000e+01                75.81
#        low            7.600000e+01         7.487000e+01                74.76
#        close          7.630000e+01         7.533000e+01                75.80
#        volume         1.504860e+06         1.660637e+06           1318051.00
# AAPL   open           1.739041e+02         1.716637e+02               168.99
#        high           1.748201e+02         1.731971e+02               170.66
#        low            1.721148e+02         1.696125e+02               168.42
#        close          1.734958e+02         1.702099e+02               170.41
#        volume         2.823959e+07         3.174169e+07          23819966.00
#
# date           2019-02-11 00:00:00  2019-02-12 00:00:00  2019-02-13 00:00:00  \
# ticker
# A      open           7.600000e+01                76.80         7.737000e+01
#        high           7.639000e+01                77.25         7.749000e+01
#        low            7.574750e+01                76.43         7.674410e+01
#        close          7.608000e+01                77.07         7.725000e+01
#        volume         1.018208e+06           2045501.00         1.376358e+06
# AAPL   open           1.710500e+02               170.10         1.713900e+02
#        high           1.712100e+02               171.00         1.724800e+02
#        low            1.692500e+02               169.70         1.699200e+02
#        close          1.694300e+02               170.89         1.701800e+02
#        volume         2.099342e+07          22283523.00         2.249023e+07
#
# date           2019-02-14 00:00:00  2019-02-15 00:00:00  ticker
# ticker
# A      open           7.700000e+01                77.63       A
#        high           7.728000e+01                78.31       A
#        low            7.652000e+01                77.47       A
#        close          7.702000e+01                78.30       A
#        volume         1.618269e+06           1919672.00       A
# AAPL   open           1.697100e+02               171.25    AAPL
#        high           1.712615e+02               171.70    AAPL
#        low            1.693800e+02               169.75    AAPL
#        close          1.708000e+02               170.42    AAPL
#        volume         2.183575e+07          24626814.00    AAPL
#
# [10 rows x 1260 columns]

# %%
result
# Out:
# date           2014-02-18 00:00:00  2014-02-19 00:00:00  2014-02-20 00:00:00  \
# ticker
# A      open           3.770190e+01         3.745000e+01         3.821930e+01
#        high           3.815130e+01         3.856650e+01         3.916900e+01
#        low            3.741600e+01         3.737520e+01         3.815470e+01
#        close          3.754540e+01         3.808320e+01         3.900220e+01
#        volume         6.553839e+06         4.838795e+06         4.629755e+06
#
# date           2014-02-21 00:00:00  2014-02-24 00:00:00  2014-02-25 00:00:00  \
# ticker
# A      open           3.897500e+01         3.843040e+01         3.866870e+01
#        high           3.907710e+01         3.879120e+01         3.919290e+01
#        low            3.834190e+01         3.839630e+01         3.863460e+01
#        close          3.835550e+01         3.863460e+01         3.872990e+01
#        volume         2.407171e+06         2.392783e+06         3.375173e+06
#
# date           2014-02-26 00:00:00  2014-02-27 00:00:00  2014-02-28 00:00:00  \
# ticker
# A      open           3.879120e+01         3.881840e+01         3.843040e+01
#        high           3.922690e+01         3.899540e+01         3.887970e+01
#        low            3.863460e+01         3.825340e+01         3.839630e+01
#        close          3.887290e+01         3.836910e+01         3.875720e+01
#        volume         2.400946e+06         3.123781e+06         2.876261e+06
#
# date           2014-03-03 00:00:00   ...    2019-02-05 00:00:00  \
# ticker                               ...
# A      open           3.820570e+01   ...                  75.80
#        high           3.888650e+01   ...                  76.51
#        low            3.797770e+01   ...                  75.79
#        close          3.860740e+01   ...                  76.31
#        volume         2.488373e+06   ...             1593537.00
#
# date           2019-02-06 00:00:00  2019-02-07 00:00:00  2019-02-08 00:00:00  \
# ticker
# A      open                  76.11                75.72                75.07
#        high                  76.69                76.12                75.81
#        low                   76.00                74.87                74.76
#        close                 76.30                75.33                75.80
#        volume           1504860.00           1660637.00           1318051.00
#
# date           2019-02-11 00:00:00  2019-02-12 00:00:00  2019-02-13 00:00:00  \
# ticker
# A      open           7.600000e+01                76.80         7.737000e+01
#        high           7.639000e+01                77.25         7.749000e+01
#        low            7.574750e+01                76.43         7.674410e+01
#        close          7.608000e+01                77.07         7.725000e+01
#        volume         1.018208e+06           2045501.00         1.376358e+06
#
# date           2019-02-14 00:00:00  2019-02-15 00:00:00  ticker
# ticker
# A      open                  77.00                77.63       A
#        high                  77.28                78.31       A
#        low                   76.52                77.47       A
#        close                 77.02                78.30       A
#        volume           1618269.00           1919672.00       A
#
# [5 rows x 1260 columns]
