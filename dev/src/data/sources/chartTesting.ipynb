# 661011      668296  2019-01-31  385.2246  387.0405  380.1700  383.6923
# 661012      668297  2019-02-01  384.1798  390.8364  382.8031  385.4932
# 661013      668298  2019-02-04  387.0255  395.0850  386.1798  395.0154
# 661014      668299  2019-02-05  398.7467  408.6967  397.5527  408.1295
# 661015      668300  2019-02-06  409.4529  411.8110  403.6321  409.0549
# 661016      668301  2019-02-07  407.9300  410.3500  402.2900  405.1700
# 661017      668302  2019-02-08  400.0000  404.9600  397.8000  404.9100
# 661018      668303  2019-02-11  408.1000  409.8300  402.6900  403.9500
# 661019      668304  2019-02-12  407.0000  411.2100  405.3950  410.7200
# 661020      668305  2019-02-13  412.5200  412.7200  407.6700  410.5800
# 661021      668306  2019-02-14  408.9300  412.2200  407.8000  409.8200
# 661022      668307  2019-02-15  412.4800  418.0500  411.4300  417.9700
#
#           volume ticker
# 659764   4653262     BA
# 659765   5149154     BA
# 659766   4470511     BA
# 659767   5170064     BA
# 659768   4638248     BA
# 659769   7317397     BA
# 659770   4804395     BA
# 659771   4649978     BA
# 659772   4365211     BA
# 659773   4847051     BA
# 659774   5423308     BA
# 659775   4097125     BA
# 659776   3599923     BA
# 659777   4301861     BA
# 659778   7039871     BA
# 659779   4190977     BA
# 659780   5041992     BA
# 659781   6071160     BA
# 659782   5702757     BA
# 659783   4381634     BA
# 659784   4151560     BA
# 659785   6672961     BA
# 659786   4601670     BA
# 659787   7975403     BA
# 659788   4476014     BA
# 659789   3229412     BA
# 659790   3091527     BA
# 659791   3116046     BA
# 659792   2863453     BA
# 659793   2962010     BA
# ...          ...    ...
# 660993   4448759     BA
# 660994   4030280     BA
# 660995   4736472     BA
# 660996   4213870     BA
# 660997   5358117     BA
# 660998   3158852     BA
# 660999   2476367     BA
# 661000   2940908     BA
# 661001   2731082     BA
# 661002   4270365     BA
# 661003   4256505     BA
# 661004   4336541     BA
# 661005   2924874     BA
# 661006   2801392     BA
# 661007   3190425     BA
# 661008   3128884     BA
# 661009   3202652     BA
# 661010  12705305     BA
# 661011   6878455     BA
# 661012   5625749     BA
# 661013   4256562     BA
# 661014   7230380     BA
# 661015   5356025     BA
# 661016   5211412     BA
# 661017   4570946     BA
# 661018   3046932     BA
# 661019   3263321     BA
# 661020   3078692     BA
# 661021   2724260     BA
# 661022   4017338     BA
#
# [1259 rows x 8 columns]

# %%
mondays = WeekdayLocator(MONDAY)        # major ticks on the mondays
alldays = DayLocator()              # minor ticks on the days
weekFormatter = DateFormatter('%b %d')  # e.g., Jan 12
dayFormatter = DateFormatter('%d') # e.g., 12
chosenStock['date']=pd.to_datetime(chosenStock['date'],infer_datetime_format=True)
#chosenStock['date']= date2num(chosenStock['date'])
quotes =[chosenStock['date'],chosenStock['open'],chosenStock['close'],chosenStock['high'],chosenStock['low']]
#candlestick2_ohlc(ax,chosenStock['open'],chosenStock['high'],chosenStock['low'],chosenStock['close'])
#candlestick_ochl(ax,quotes)
# Out:
# /home/robot-tumas/pyEnv/wiggles/lib/python3.5/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
from bokeh.plotting import figure, show, output_file
#time_in_datetime = datetime.strptime(chosenStock['date'], "%Y-%m-%d")

inc = chosenStock.close > chosenStock.open
dec = chosenStock.open > chosenStock.close
w = 12*60*60*1000 # half day in ms
title = chosenStock['ticker'].iloc[0] + ' Chart'
TOOLS = "pan,wheel_zoom,box_zoom,reset,save"
p = figure(x_axis_type="datetime", tools=TOOLS, plot_width=1000, title = title)
p.xaxis.major_label_orientation = 3.14/4
p.grid.grid_line_alpha=0.3
p.segment(chosenStock['date'], chosenStock['high'],chosenStock['date'], chosenStock['low'], color="black")
p.vbar(chosenStock.date[inc], w, chosenStock.open[inc], chosenStock.close[inc], fill_color="#D5E1DD", line_color="black")
p.vbar(chosenStock.date[dec], w, chosenStock.open[dec], chosenStock.close[dec], fill_color="#F2583E", line_color="black")
show(p)
